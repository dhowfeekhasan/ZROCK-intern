# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT THE DATASET**

# %%
df = pd.read_csv('temperatures.csv')
df  #in this dataset all the temperature readings in celsius
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.shape #there are 117 rows and 18 columns
# Out:
# (117, 18)

# %%
df.size #total no.of data is 2106
# Out:
# 2106

# %%
df.info() #in this datset,there is only numbers(float64)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %%
df.duplicated().sum() #checking duplicates
# Out:
# 0

# %%
df.isnull().sum() #missing values
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
df.loc[:, 'JAN':'DEC']
# Out:
#        JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0    22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1    24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2    23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3    22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4    22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04  30.27
# 113  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68  30.29
# 114  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55  31.04
# 115  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66  31.98
# 116  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22  32.29
#
#        NOV    DEC
# 0    27.31  24.49
# 1    26.31  24.04
# 2    26.08  23.65
# ...

# %%
df.loc[:, 'JAN':'DEC'].mean()
# Out:
# JAN    23.687436
# FEB    25.597863
# MAR    29.085983
# APR    31.975812
# MAY    33.565299
# JUN    32.774274
# JUL    31.035897
# AUG    30.507692
# SEP    30.486752
# OCT    29.766581
# NOV    27.285470
# DEC    24.608291
# dtype: float64

# %% [markdown]
# **Visualizing the monthly trends in barchart and pie chart**

# %%
a = df.loc[:, 'JAN':'DEC'].mean().plot(kind='bar', figsize=(4,4))
a.set_xlabel("Months")
a.set_ylabel("Average of the months")
a.set_title("Average of the each months")
# Out:
# Text(0.5, 1.0, 'Average of the each months')

# %%
a = df.loc[:, 'JAN':'DEC'].mean().plot(kind='pie', figsize=(4,4))
a.set_title("Average of the each months")
# Out:
# Text(0.5, 1.0, 'Average of the each months')

# %% [markdown]
# **Outliers**

# %%
def identify_outliers(df, columns):   #IQR
    outliers = {}
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[column] = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers

 #for each month
outliers = identify_outliers(df, df.columns[1:13])

# Display the outliers
for month, values in outliers.items():
    print(f"Outliers in {month}:")
    print(values)
    print()
# Out:
# Outliers in JAN:
# 115    26.94
# 116    26.45
# Name: JAN, dtype: float64
#
# Outliers in FEB:
# 105    29.33
# 115    29.72
# 116    29.46
# Name: FEB, dtype: float64
#
# Outliers in MAR:
# 103    32.33
# 109    31.94
# 115    32.62
# 116    31.60
# Name: MAR, dtype: float64
#
# Outliers in APR:
# 4      30.01
# 109    34.07
# 115    35.38
# 116    34.95
# Name: APR, dtype: float64
#
# Outliers in MAY:
# 20     35.84
# 115    35.72
# 116    35.84
# Name: MAY, dtype: float64
#
# Outliers in JUN:
# 94    34.48
# Name: JUN, dtype: float64
#
# Outliers in JUL:
# 8      29.81
# 55     29.76
# 86     32.28
# 101    32.76
# Name: JUL, dtype: float64
#
# Outliers in AUG:
# 108    31.84
# 115    31.79
# 116    31.72
# Name: AUG, dtype: float64
#
# Outliers in SEP:
# 16     29.07
# 116    32.22
# Name: SEP, dtype: float64
#
# Outliers in OCT:
# 16     27.90
# 115    31.98
# 116    32.29
# Name: OCT, dtype: float64
#
# Outliers in NOV:
# 115    30.11
# 116    29.60
# ...

# %% [markdown]
# **Visulizing the outliers using sns **

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(data=df.loc[:, 'JAN':'DEC'], palette='coolwarm')
plt.xlabel("Months")
plt.ylabel("Temperature (°C)")
plt.title("Monthly Temperature Distribution (outliers)")
plt.show()
